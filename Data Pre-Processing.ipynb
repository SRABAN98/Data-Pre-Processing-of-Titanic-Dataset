# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv("train.csv")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
del train["Name"]
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
del train["Ticket"]
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
del train["Fare"]
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Cabin Embarked
# 0            1         0       3    male  22.0      1      0   NaN        S
# 1            2         1       1  female  38.0      1      0   C85        C
# 2            3         1       3  female  26.0      0      0   NaN        S
# 3            4         1       1  female  35.0      1      0  C123        S
# 4            5         0       3    male  35.0      0      0   NaN        S

# %%
del train["Cabin"]
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            1         0       3    male  22.0      1      0        S
# 1            2         1       1  female  38.0      1      0        C
# 2            3         1       3  female  26.0      0      0        S
# 3            4         1       1  female  35.0      1      0        S
# 4            5         0       3    male  35.0      0      0        S

# %%
def getNumber(str):
    if str=="male":
        return 1
    else:
        return 2
train["Gender"] = train["Sex"].apply(getNumber)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3    male  22.0      1      0        S       1
# 1            2         1       1  female  38.0      1      0        C       2
# 2            3         1       3  female  26.0      0      0        S       2
# 3            4         1       1  female  35.0      1      0        S       2
# 4            5         0       3    male  35.0      0      0        S       1

# %%
del train["Sex"]
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3  22.0      1      0        S       1
# 1            2         1       1  38.0      1      0        C       2
# 2            3         1       3  26.0      0      0        S       2
# 3            4         1       1  35.0      1      0        S       2
# 4            5         0       3  35.0      0      0        S       1

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# dtype: int64

# %%
meanS = train[train.Survived==1].Age.mean()
meanS
# Out:
# 28.343689655172415

# %%
meanNS = train[train.Survived==0].Age.mean()
meanNS
# Out:
# 30.62617924528302

# %%
train["age"] = np.where(pd.isnull(train.Age) & train["Survived"]==1  ,meanS, train["Age"])
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# age            125
# dtype: int64

# %%
train.age.fillna(meanNS,inplace=True)
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# age              0
# dtype: int64

# %%
del train["Age"]
train.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
survivedQ = train[train.Embarked == 'Q'][train.Survived == 1].shape[0]
survivedC = train[train.Embarked == 'C'][train.Survived == 1].shape[0]
survivedS = train[train.Embarked == 'S'][train.Survived == 1].shape[0]
print(survivedQ)
print(survivedC)
print(survivedS)
# Out:
# 30
# 93
# 217

# %%
survivedQ = train[train.Embarked == 'Q'][train.Survived == 0].shape[0]
survivedC = train[train.Embarked == 'C'][train.Survived == 0].shape[0]
survivedS = train[train.Embarked == 'S'][train.Survived == 0].shape[0]
print(survivedQ)
print(survivedC)
print(survivedS)
# Out:
# 47
# 75
# 427

# %%
train.dropna(inplace=True)
train.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# SibSp          0
# Parch          0
# Embarked       0
# Gender         0
# age            0
# dtype: int64

# %%
train.rename(columns={'age':'Age'}, inplace=True)
train.rename(columns={'Gender':'Sex'}, inplace=True)
train.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age
# 0            1         0       3      1      0        S    1  22.0
# 1            2         1       1      1      0        C    2  38.0
# 2            3         1       3      0      0        S    2  26.0
# 3            4         1       1      1      0        S    2  35.0
# 4            5         0       3      0      0        S    1  35.0

# %%
def getEmb(str):
    if str == "S":
        return 1
    elif str == 'Q':
        return 2
    else:
        return 3
train["Embark"] = train["Embarked"].apply(getEmb)
train.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age  Embark
# 0            1         0       3      1      0        S    1  22.0       1
# 1            2         1       1      1      0        C    2  38.0       3
# 2            3         1       3      0      0        S    2  26.0       1
# 3            4         1       1      1      0        S    2  35.0       1
# 4            5         0       3      0      0        S    1  35.0       1

# %%
del train["Embarked"]
train.rename(columns={"Embark":"Embarked"}, inplace=True)
train.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch  Sex   Age  Embarked
# 0            1         0       3      1      0    1  22.0         1
# 1            2         1       1      1      0    2  38.0         3
# 2            3         1       3      0      0    2  26.0         1
# 3            4         1       1      1      0    2  35.0         1
# 4            5         0       3      0      0    1  35.0         1

# %%
males = (train["Sex"] == 1).sum()
females = (train["Sex"] == 2).sum()
print(males)
print(females)
p = [males, females]
plt.pie(p,labels = ["Male","Female"],colors = ["green","yellow"], explode = (0.05, 0), startangle = 0)  
plt.axis("equal") 
plt.show()
# Out:
# 577
# 312

# %%
MaleS = train[train.Sex == 1][train.Survived == 1].shape[0]
print(MaleS)
MaleNS = train[train.Sex == 1][train.Survived == 0].shape[0]
print(MaleNS)
FemaleS = train[train.Sex == 2][train.Survived == 1].shape[0]
print(FemaleS)
FemaleNS = train[train.Sex == 2][train.Survived == 0].shape[0]
print(FemaleNS)
# Out:
# 109
# 468
# 231
# 81

# %%
chart = [MaleS,MaleNS,FemaleS,FemaleNS]
colors = ["lightskyblue","yellowgreen","Yellow","Orange"]
labels = ["Survived Male","Not Survived Male","Survived Female","Not Survived Female"]
explode = [0,0.05,0,0.1]
plt.pie(chart,labels = labels,colors = colors,explode = explode,startangle = 100,counterclock = False,autopct = "%.2f%%")
plt.axis("equal")
plt.show()

# %%
test = pd.read_csv("test.csv")

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
del test["Name"]
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Cabin  \
# 0          892       3    male  34.5      0      0   330911   7.8292   NaN
# 1          893       3  female  47.0      1      0   363272   7.0000   NaN
# 2          894       2    male  62.0      0      0   240276   9.6875   NaN
# 3          895       3    male  27.0      0      0   315154   8.6625   NaN
# 4          896       3  female  22.0      1      1  3101298  12.2875   NaN
#
#   Embarked
# 0        Q
# 1        S
# 2        Q
# 3        S
# 4        S

# %%
del test["Ticket"]
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0          892       3    male  34.5      0      0   7.8292   NaN        Q
# 1          893       3  female  47.0      1      0   7.0000   NaN        S
# 2          894       2    male  62.0      0      0   9.6875   NaN        Q
# 3          895       3    male  27.0      0      0   8.6625   NaN        S
# 4          896       3  female  22.0      1      1  12.2875   NaN        S

# %%
del test["Fare"]
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch Cabin Embarked
# 0          892       3    male  34.5      0      0   NaN        Q
# 1          893       3  female  47.0      1      0   NaN        S
# 2          894       2    male  62.0      0      0   NaN        Q
# 3          895       3    male  27.0      0      0   NaN        S
# 4          896       3  female  22.0      1      1   NaN        S

# %%
del test["Cabin"]
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch Embarked
# 0          892       3    male  34.5      0      0        Q
# 1          893       3  female  47.0      1      0        S
# 2          894       2    male  62.0      0      0        Q
# 3          895       3    male  27.0      0      0        S
# 4          896       3  female  22.0      1      1        S

# %%
def getNumber(str):
    if str=="male":
        return 1
    else:
        return 2
test["Gender"] = test["Sex"].apply(getNumber)

test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch Embarked  Gender
# 0          892       3    male  34.5      0      0        Q       1
# 1          893       3  female  47.0      1      0        S       2
# 2          894       2    male  62.0      0      0        Q       1
# 3          895       3    male  27.0      0      0        S       1
# 4          896       3  female  22.0      1      1        S       2

# %%
del test["Sex"]
test.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch Embarked  Gender
# 0          892       3  34.5      0      0        Q       1
# 1          893       3  47.0      1      0        S       2
# 2          894       2  62.0      0      0        Q       1
# 3          895       3  27.0      0      0        S       1
# 4          896       3  22.0      1      1        S       2

# %%
test.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Age            86
# SibSp           0
# Parch           0
# Embarked        0
# Gender          0
# dtype: int64
